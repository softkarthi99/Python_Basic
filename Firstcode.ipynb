# %% [markdown]
# <a href="https://colab.research.google.com/github/softkarthi99/Python_Basic/blob/main/Firstcode.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# first
## Second
### third
print("Welcome.....")
# Out:
# Welcome.....

# %% [markdown]
# # Heading
#
# ## Sub Heading
#
# ### second Heading

# %% [markdown]
# # Welcome
